# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('../../datasets/competencia_01.csv', low_memory=False)

# %%
data.shape
# Out:
# (981946, 155)

# %%
data_04 = data.query('foto_mes == 202104').drop(columns=['foto_mes', 'numero_de_cliente'])

# %%
wd = pd.read_csv('../../datasets/dwalkingdead.csv', low_memory=False)

# %%
wd.groupby(['cluster', 'periodo'])['active_quarter'].value_counts(normalize=True).unstack().plot(kind='bar', stacked=True, figsize=(10, 6))
# Out:
# <Axes: xlabel='cluster,periodo'>

# %%
wd.groupby(['cluster', 'periodo'])['cliente_vip'].value_counts()
# Out:
# cluster    periodo  cliente_vip
# cluster_1  -5       0               720
#            -4       0              1325
#            -3       0              1945
#                     1                 1
#            -2       0              2426
#            -1       0              2426
# cluster_2  -5       0               149
#            -4       0               255
#            -3       0               354
#            -2       0               429
#            -1       0               429
# cluster_3  -5       0               132
#            -4       0               282
#                     1                 2
#            -3       0               424
#                     1                 2
#            -2       0               518
#                     1                 2
#            -1       0               518
#                     1                 2
# cluster_4  -5       0               179
#            -4       0               289
#            -3       0               447
# ...

# %%
wd.groupby(['cluster', 'periodo'])['internet'].value_counts(normalize=True).unstack().plot(kind='bar', stacked=True, figsize=(10, 6))
# Out:
# <Axes: xlabel='cluster,periodo'>

# %%
wd.groupby(['cluster', 'periodo'])['cliente_edad'].agg(['mean', 'std']).plot(kind='bar', figsize=(10, 6))
# Out:
# <Axes: xlabel='cluster,periodo'>

# %%
wd.groupby(['cluster'])['mrentabilidad'].mean().plot(kind='bar', figsize=(10, 6))
# Out:
# <Axes: xlabel='cluster'>

# %%
wd.groupby(['cluster', 'periodo'])['Master_status'].value_counts(normalize=True).unstack().plot(kind='bar', stacked=True, figsize=(10, 6))
# Out:
# <Axes: xlabel='cluster,periodo'>

# %%
wd.loc[wd.foto_mes == 202101, 'cluster'].value_counts(normalize=True) * 100
# Out:
# cluster_1    61.132267
# cluster_4    14.800711
# cluster_3    13.175933
# cluster_2    10.891089
# Name: cluster, dtype: float64
